# %%
import json

import pprint

# %%
with open('/localdisk0/GDELT/2019-vgkg-protest-image-dataset-20191030-labels.json', 'r', encoding='utf-8') as file:
    # Read each line and process it
    for line in file:
        # Parse the JSON object from the line
        json_obj = json.loads(line)
        
        # Now you can work with the JSON object
        raw_json_obj = json.loads(json_obj["RawJSON"])
        pprint.pprint(raw_json_obj, indent=4)

        break
# Out:
# {   'EXIF': {   'Composite:Camera:Main:CircleOfConfusion': '0.004 mm',
#                 'Composite:Camera:Main:FocalLength35efl': '4.2 mm (35 mm '
#                                                           'equivalent: 31.0 '
#                                                           'mm)',
#                 'Composite:Camera:Main:HyperfocalDistance': '1.97 m',
#                 'Composite:Camera:Main:ScaleFactor35efl': '7.4',
#                 'Composite:Image:Main:Aperture': '2.2',
#                 'Composite:Image:Main:FOV': '60.3 deg',
#                 'Composite:Image:Main:ImageSize': '4128x2322',
#                 'Composite:Image:Main:LightValue': '9.6',
#                 'Composite:Image:Main:Megapixels': '9.6',
#                 'Composite:Image:Main:ShutterSpeed': '1/100',
#                 'Composite:Preview:Main:ThumbnailImage': '[BINARYDATA:BYTES=16575]',
#                 'EXIF:ExifIFD:Camera:Main:ExposureMode': 'Auto',
# ...

# %%
print(labels[1])
